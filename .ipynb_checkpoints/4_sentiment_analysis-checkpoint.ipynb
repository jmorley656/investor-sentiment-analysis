# %% [markdown]
# # Sentiment Analysis (textacy)

# %% [markdown]
# Textacy Notebook

# %% [markdown]
# ## Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm_notebook
import textacy
from collections import defaultdict
import re

sns.set(font_scale=1.5)
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %% [markdown]
# ## Load the GGP data

# %%
df = pd.read_csv('resources/scrape1_model_predictions.csv')

# %%
df.head()
# Out:
#           date      user                        title  \
# 0  31 Jan 2022  JiffyBag                      RE: SAS
# 1  31 Jan 2022  JiffyBag                      RE: SAS
# 2  31 Jan 2022  rosso123  Newcrest pulling a fast one
# 3  31 Jan 2022  JiffyBag   RE: Why would u short this
# 4  31 Jan 2022  Philbrim                 Ups n downs.
#
#                                              comment     opinion  price  \
# 0  For me, it was just a fun exercise to do, and ...  No Opinion   13.8
# 1  Hi Walkabout,I fully acknoweldege your rationa...  No Opinion   13.8
# 2  NCM wants this 5% done and dusted asap, otherw...  No Opinion   13.8
# 3  Merc,It would be fantastic if someone could ac...  No Opinion   13.8
# 4  We go down 5% and most people are so volatile....  No Opinion   13.8
#
#      datetime                                      comment_clean  \
# 0  2022-01-31  for was just fun exercise and will have see wh...
# 1  2022-01-31  walkabouti fully acknoweldege your rationale e...
# 2  2022-01-31  ncm wants this done and dusted asap otherwise ...
# 3  2022-01-31  mercit would fantastic someone could actually ...
# 4  2022-01-31  down and most people are volatile and everyone...
#
#    predicted_opinion
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1

# %% [markdown]
# ## Sentiment Analysis using Sentiment Words csv

# %% [markdown]
# Load sentiment words

# %%
sen = pd.read_csv('resources/sentiment_words.csv')

# %%
sen['objectivity'] = 1. - (sen.pos_score + sen.neg_score)
sen['pos_vs_neg'] = sen.pos_score - sen.neg_score

# %%
sen_dict = defaultdict(dict) # set up a default dictionary with an empty dictionary as default value

for row in tqdm_notebook(sen.itertuples()):
    sen_dict[row.pos] [row.word] = {'objectivity': row.objectivity, 'pos_vs_neg': row.pos_vs_neg}
# Out:
# /Users/jamesmorley/opt/anaconda3/envs/textacy/lib/python3.7/site-packages/ipykernel_launcher.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0it [00:00, ?it/s]

# %%
sen_dict
# Out:
# defaultdict(dict,
#             {'adj': {'.22-caliber': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '.22-calibre': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '.22_caliber': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '.22_calibre': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '.38-caliber': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '.38-calibre': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '.38_caliber': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '.38_calibre': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '.45-caliber': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '.45-calibre': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '.45_caliber': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '.45_calibre': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '0': {'objectivity': 0.5, 'pos_vs_neg': -0.5},
#               '1': {'objectivity': 0.75, 'pos_vs_neg': -0.25},
#               '10': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '10-membered': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '100': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '1000': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '1000th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '100th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '101': {'objectivity': 0.75, 'pos_vs_neg': -0.25},
#               '101st': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '105': {'objectivity': 0.75, 'pos_vs_neg': -0.25},
#               '105th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '10th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '11': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '110': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '110th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '115': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '115th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '11th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '12': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '120': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '120th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '125': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               '125th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '12th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '13': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '130': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '130th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '135': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               '135th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '13th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '14': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '140': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '140th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '145': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               '145th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '14th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '15': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '150': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '150th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '155': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               '155th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '15th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '16': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '160': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '160th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '165': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               '165th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '16th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '17': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '170': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '170th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '175': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               '175th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '17th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '18': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '180': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '180th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '18th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '19': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '190': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '190th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '19th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '1st': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '2': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '2-dimensional': {'objectivity': 0.375, 'pos_vs_neg': -0.625},
#               '20': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '200': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '200th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '20th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '21': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '21st': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '22': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '22nd': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '23': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '23rd': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '24': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '24th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '25': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '25th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '26': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '26th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '27': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '27th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '28': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '28th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '29': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '29th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '2d': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '2nd': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '3': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '3-dimensional': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '3-membered': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '30': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '300': {'objectivity': 0.75, 'pos_vs_neg': -0.25},
#               '300th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '30th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '31': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '31st': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '32': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '32nd': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '33': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '33rd': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '34': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '34th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '35': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '35th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '36': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '36th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '37': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '37th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '38': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '38th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '39': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '39th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '3rd': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '4': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '4-dimensional': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '4-membered': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '40': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '400': {'objectivity': 0.75, 'pos_vs_neg': -0.25},
#               '400th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '40th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '41': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '41st': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '42': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '42nd': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '43': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '43rd': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '44': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '44th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '45': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '45th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '46': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '46th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '47': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '47th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '48': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '48th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '49': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '49th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '4th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '5': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '5-membered': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '50': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '500': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '500th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '50th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '51': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '52': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '53': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '54': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '55': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '55th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '56': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '57': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '58': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '59': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '5th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '6': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '6-membered': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '60': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '60th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '61': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '62': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '63': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '64': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '64th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '65': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '65th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '66': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '67': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '68': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '69': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '6th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '7': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '7-membered': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '70': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '70th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '71': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '72': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '73': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '74': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '75': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '75th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '76': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '77': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '78': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '79': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '7th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '8': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '8-membered': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '80': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '80th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '81': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '82': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '83': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '84': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '85': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '85th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '86': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '87': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '88': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '89': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '8th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '9': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '9-membered': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '90': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '90th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '91': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '92': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '93': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '94': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '95': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '95th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '96': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '97': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '98': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '99': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               '9th': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'a-ok': {'objectivity': 0.875, 'pos_vs_neg': 0.125},
#               'a-okay': {'objectivity': 0.875, 'pos_vs_neg': 0.125},
#               'a-one': {'objectivity': 0.375, 'pos_vs_neg': 0.625},
#               'a.m.': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'a_cappella': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'a_couple_of': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'a_few': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'a_la_carte': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'a_la_mode': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'a_posteriori': {'objectivity': 0.8125, 'pos_vs_neg': 0.0625},
#               'a_priori': {'objectivity': 0.75, 'pos_vs_neg': 0.0},
#               'abactinal': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'abandoned': {'objectivity': 0.5625, 'pos_vs_neg': 0.0625},
#               'abashed': {'objectivity': 0.625, 'pos_vs_neg': -0.375},
#               'abasic': {'objectivity': 0.5, 'pos_vs_neg': -0.25},
#               'abatable': {'objectivity': 0.375, 'pos_vs_neg': 0.625},
#               'abatic': {'objectivity': 0.5, 'pos_vs_neg': -0.25},
#               'abaxial': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'abbatial': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'abbreviated': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'abdicable': {'objectivity': 0.375, 'pos_vs_neg': 0.375},
#               'abdominal': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'abdominous': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'abdominovesical': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'abducent': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'abducting': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'abecedarian': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'aberdonian': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'aberrant': {'objectivity': 0.375, 'pos_vs_neg': 0.375},
#               'abeyant': {'objectivity': 0.375, 'pos_vs_neg': -0.125},
#               'abhorrent': {'objectivity': 0.25, 'pos_vs_neg': -0.75},
#               'abiding': {'objectivity': 0.625, 'pos_vs_neg': 0.375},
#               'abient': {'objectivity': 0.25, 'pos_vs_neg': 0.25},
#               'abiogenetic': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'abject': {'objectivity': 0.125, 'pos_vs_neg': -0.3125},
#               'abkhaz': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'abkhazian': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'ablated': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               'ablative': {'objectivity': 0.6875, 'pos_vs_neg': 0.3125},
#               'ablaze': {'objectivity': 0.84375, 'pos_vs_neg': 0.03125},
#               'able': {'objectivity': 0.84375, 'pos_vs_neg': 0.15625},
#               'able-bodied': {'objectivity': 0.75, 'pos_vs_neg': 0.25},
#               'abloom': {'objectivity': 0.875, 'pos_vs_neg': 0.125},
#               'ablutionary': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'abnaki': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'abnormal': {'objectivity': 0.45833333333299997,
#                'pos_vs_neg': -0.208333333333},
#               'abolishable': {'objectivity': 0.375, 'pos_vs_neg': 0.625},
#               'abolitionary': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'abomasal': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'abominable': {'objectivity': 0.4375, 'pos_vs_neg': -0.5625},
#               'aboral': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'aboriginal': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'abortifacient': {'objectivity': 0.625, 'pos_vs_neg': -0.375},
#               'abortive': {'objectivity': 0.75, 'pos_vs_neg': -0.25},
#               'aboulic': {'objectivity': 0.25, 'pos_vs_neg': -0.75},
#               'abounding': {'objectivity': 0.75, 'pos_vs_neg': -0.25},
#               'about': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'above': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               'above-mentioned': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               'above-named': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               'aboveboard': {'objectivity': 0.125, 'pos_vs_neg': -0.375},
#               'aboveground': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'abranchial': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'abranchiate': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'abranchious': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'abrasive': {'objectivity': 0.3125,
#                'pos_vs_neg': -0.35450000000000004},
#               'abreast': {'objectivity': 0.75, 'pos_vs_neg': 0.25},
#               'abridged': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'abroach': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'abroad': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'abrupt': {'objectivity': 0.4375, 'pos_vs_neg': 0.0},
#               'abruptly-pinnate': {'objectivity': 0.75, 'pos_vs_neg': 0.25},
#               'abscessed': {'objectivity': 0.5, 'pos_vs_neg': -0.5},
#               'absent': {'objectivity': 0.375,
#                'pos_vs_neg': -0.29166666666600005},
#               'absentminded': {'objectivity': 0.5, 'pos_vs_neg': 0.25},
#               'absolute': {'objectivity': 0.375,
#                'pos_vs_neg': -0.025000000000000022},
#               'absolutist': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'absolutistic': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'absolved': {'objectivity': 0.375, 'pos_vs_neg': 0.625},
#               'absolvitory': {'objectivity': 0.75, 'pos_vs_neg': 0.25},
#               'absorbable': {'objectivity': 0.5, 'pos_vs_neg': 0.5},
#               'absorbed': {'objectivity': 0.8125, 'pos_vs_neg': 0.0625},
#               'absorbefacient': {'objectivity': 0.625, 'pos_vs_neg': 0.375},
#               'absorbent': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'absorbing': {'objectivity': 0.5, 'pos_vs_neg': 0.5},
#               'absorptive': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'abstemious': {'objectivity': 0.625, 'pos_vs_neg': 0.25},
#               'abstentious': {'objectivity': 0.375, 'pos_vs_neg': -0.625},
#               'abstinent': {'objectivity': 0.375, 'pos_vs_neg': -0.625},
#               'abstract': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'abstracted': {'objectivity': 0.5, 'pos_vs_neg': 0.25},
#               'abstractionist': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'abstractive': {'objectivity': 0.625, 'pos_vs_neg': 0.375},
#               'abstruse': {'objectivity': 0.125, 'pos_vs_neg': 0.125},
#               'absurd': {'objectivity': 0.5, 'pos_vs_neg': 0.5},
#               'abulic': {'objectivity': 0.25, 'pos_vs_neg': -0.75},
#               'abundant': {'objectivity': 0.75, 'pos_vs_neg': -0.25},
#               'abused': {'objectivity': 0.4375, 'pos_vs_neg': -0.1875},
#               'abusive': {'objectivity': 0.125, 'pos_vs_neg': -0.875},
#               'abuzz': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'abysmal': {'objectivity': 0.75, 'pos_vs_neg': 0.0},
#               'abyssal': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'academic': {'objectivity': 0.625,
#                'pos_vs_neg': -0.041666666665999996},
#               'acanthoid': {'objectivity': 0.875, 'pos_vs_neg': 0.125},
#               'acanthotic': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acanthous': {'objectivity': 0.875, 'pos_vs_neg': 0.125},
#               'acapnial': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acapnic': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acapnotic': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acarpellous': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acarpelous': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acarpous': {'objectivity': 0.625, 'pos_vs_neg': -0.375},
#               'acatalectic': {'objectivity': 0.875, 'pos_vs_neg': 0.125},
#               'acaudal': {'objectivity': 0.75, 'pos_vs_neg': -0.25},
#               'acaudate': {'objectivity': 0.75, 'pos_vs_neg': -0.25},
#               'acaulescent': {'objectivity': 0.75, 'pos_vs_neg': 0.25},
#               'accelerando': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'accelerated': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'accelerative': {'objectivity': 0.625, 'pos_vs_neg': -0.125},
#               'acceleratory': {'objectivity': 0.625, 'pos_vs_neg': -0.125},
#               'accented': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'accentual': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acceptable': {'objectivity': 0.59375, 'pos_vs_neg': 0.40625},
#               'acceptant': {'objectivity': 0.75, 'pos_vs_neg': 0.25},
#               'accepted': {'objectivity': 0.5, 'pos_vs_neg': 0.5},
#               'accepting': {'objectivity': 0.5, 'pos_vs_neg': 0.25},
#               'acceptive': {'objectivity': 0.5625, 'pos_vs_neg': 0.1875},
#               'accessary': {'objectivity': 0.625, 'pos_vs_neg': 0.375},
#               'accessible': {'objectivity': 0.59375, 'pos_vs_neg': 0.34375},
#               'accessional': {'objectivity': 0.875, 'pos_vs_neg': 0.125},
#               'accessorial': {'objectivity': 0.625, 'pos_vs_neg': 0.375},
#               'accessory': {'objectivity': 0.8125, 'pos_vs_neg': 0.1875},
#               'accident-prone': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               'accidental': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               'accipitrine': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acclivitous': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'accommodating': {'objectivity': 0.5, 'pos_vs_neg': 0.5},
#               'accommodational': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'accommodative': {'objectivity': 0.5833333333333,
#                'pos_vs_neg': 0.3333333333333},
#               'accompanied': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'accompanying': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'accomplishable': {'objectivity': 0.75, 'pos_vs_neg': 0.25},
#               'accomplished': {'objectivity': 0.708333333333,
#                'pos_vs_neg': 0.291666666667},
#               'accordant': {'objectivity': 0.75, 'pos_vs_neg': 0.25},
#               'according': {'objectivity': 0.9375, 'pos_vs_neg': 0.0625},
#               'accountable': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'accoutered': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'accoutred': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'accredited': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'accretionary': {'objectivity': 0.625, 'pos_vs_neg': -0.375},
#               'accretive': {'objectivity': 0.75, 'pos_vs_neg': -0.25},
#               'accrued': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acculturational': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acculturative': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'accumbent': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               'accumulated': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'accumulative': {'objectivity': 0.8125, 'pos_vs_neg': 0.1875},
#               'accurate': {'objectivity': 0.6875, 'pos_vs_neg': 0.3125},
#               'accursed': {'objectivity': 0.75, 'pos_vs_neg': -0.25},
#               'accurst': {'objectivity': 0.75, 'pos_vs_neg': -0.25},
#               'accusative': {'objectivity': 0.75, 'pos_vs_neg': -0.25},
#               'accusatorial': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'accusatory': {'objectivity': 0.5, 'pos_vs_neg': -0.5},
#               'accusing': {'objectivity': 0.5, 'pos_vs_neg': -0.5},
#               'accusive': {'objectivity': 0.5, 'pos_vs_neg': -0.5},
#               'accustomed': {'objectivity': 0.75, 'pos_vs_neg': 0.25},
#               'ace': {'objectivity': 0.375, 'pos_vs_neg': 0.625},
#               'acellular': {'objectivity': 0.5, 'pos_vs_neg': -0.5},
#               'acentric': {'objectivity': 0.5, 'pos_vs_neg': -0.375},
#               'acephalous': {'objectivity': 0.625, 'pos_vs_neg': 0.125},
#               'acerate': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acerb': {'objectivity': 0.4375, 'pos_vs_neg': -0.4375},
#               'acerbic': {'objectivity': 0.4375, 'pos_vs_neg': -0.4375},
#               'acerose': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acervate': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acetabular': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acetic': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acetonic': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acetose': {'objectivity': 0.75, 'pos_vs_neg': -0.25},
#               'acetous': {'objectivity': 0.75, 'pos_vs_neg': -0.25},
#               'acetylenic': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acetylic': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'achaean': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'achenial': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acheronian': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               'acherontic': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               'achievable': {'objectivity': 0.75, 'pos_vs_neg': 0.25},
#               'aching': {'objectivity': 0.25, 'pos_vs_neg': -0.75},
#               'achlamydeous': {'objectivity': 0.375, 'pos_vs_neg': -0.625},
#               'achlorhydric': {'objectivity': 0.5, 'pos_vs_neg': -0.25},
#               'achondritic': {'objectivity': 0.6875, 'pos_vs_neg': -0.3125},
#               'achondroplastic': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               'achromatic': {'objectivity': 0.375, 'pos_vs_neg': -0.125},
#               'achromatinic': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'achromatous': {'objectivity': 0.625, 'pos_vs_neg': -0.375},
#               'achromic': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'achromous': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'achy': {'objectivity': 0.25, 'pos_vs_neg': -0.75},
#               'acicular': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'aciculate': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acid': {'objectivity': 0.5000000000003,
#                'pos_vs_neg': -0.41666666666630003},
#               'acid-fast': {'objectivity': 0.5, 'pos_vs_neg': -0.25},
#               'acid-forming': {'objectivity': 0.5, 'pos_vs_neg': -0.5},
#               'acid-loving': {'objectivity': 0.75, 'pos_vs_neg': -0.25},
#               'acid-tasting': {'objectivity': 0.5, 'pos_vs_neg': -0.5},
#               'acidic': {'objectivity': 0.6875, 'pos_vs_neg': -0.1875},
#               'acidimetric': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acidophilic': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acidophilous': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acidotic': {'objectivity': 0.5, 'pos_vs_neg': 0.25},
#               'acidulent': {'objectivity': 0.5, 'pos_vs_neg': -0.25},
#               'acidulous': {'objectivity': 0.5, 'pos_vs_neg': -0.25},
#               'aciduric': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acinar': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acinic': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acinose': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acinous': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acknowledgeable': {'objectivity': 0.375, 'pos_vs_neg': 0.625},
#               'acknowledged': {'objectivity': 0.8125, 'pos_vs_neg': 0.1875},
#               'acned': {'objectivity': 0.625, 'pos_vs_neg': -0.375},
#               'acneiform': {'objectivity': 0.5, 'pos_vs_neg': -0.25},
#               'acold': {'objectivity': 0.375, 'pos_vs_neg': -0.625},
#               'acorn-shaped': {'objectivity': 0.875, 'pos_vs_neg': 0.125},
#               'acoustic': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acoustical': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acquainted': {'objectivity': 0.375, 'pos_vs_neg': 0.625},
#               'acquiescent': {'objectivity': 0.75, 'pos_vs_neg': 0.25},
#               'acquirable': {'objectivity': 0.375, 'pos_vs_neg': 0.625},
#               'acquired': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acquisitive': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acquitted': {'objectivity': 0.125, 'pos_vs_neg': -0.125},
#               'acrid': {'objectivity': 0.5625, 'pos_vs_neg': -0.1875},
#               'acrimonious': {'objectivity': 0.25, 'pos_vs_neg': 0.25},
#               'acritical': {'objectivity': 0.0, 'pos_vs_neg': -0.25},
#               'acrobatic': {'objectivity': 0.625, 'pos_vs_neg': 0.375},
#               'acrocarpous': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acrocentric': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acrogenic': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acrogenous': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acromegalic': {'objectivity': 0.625, 'pos_vs_neg': -0.375},
#               'acronymic': {'objectivity': 0.5, 'pos_vs_neg': 0.25},
#               'acronymous': {'objectivity': 0.5, 'pos_vs_neg': 0.25},
#               'acropetal': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acrophobic': {'objectivity': 0.25, 'pos_vs_neg': -0.75},
#               'acroscopic': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'across-the-board': {'objectivity': 0.625, 'pos_vs_neg': 0.375},
#               'actable': {'objectivity': 0.375, 'pos_vs_neg': 0.625},
#               'actinal': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acting': {'objectivity': 0.875, 'pos_vs_neg': 0.125},
#               'actinic': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'actinoid': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'actinometric': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'actinometrical': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'actinomorphic': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'actinomorphous': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'actinomycetal': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'actinomycetous': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'actinomycotic': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               'actionable': {'objectivity': 0.75, 'pos_vs_neg': 0.25},
#               'activated': {'objectivity': 0.90625, 'pos_vs_neg': -0.03125},
#               'activating': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'active': {'objectivity': 0.767857142858, 'pos_vs_neg': 0.0},
#               'activist': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'activistic': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'actual': {'objectivity': 0.575,
#                'pos_vs_neg': 0.07500000000000001},
#               'actuarial': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'actuated': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'actuating': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'acuate': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'aculeate': {'objectivity': 0.5, 'pos_vs_neg': 0.25},
#               'aculeated': {'objectivity': 0.5, 'pos_vs_neg': 0.25},
#               'acuminate': {'objectivity': 0.75, 'pos_vs_neg': 0.25},
#               'acute': {'objectivity': 0.6458333333340001,
#                'pos_vs_neg': 0.0625},
#               'acyclic': {'objectivity': 0.9375, 'pos_vs_neg': 0.0625},
#               'ad-lib': {'objectivity': 0.4375, 'pos_vs_neg': -0.5625},
#               'ad_hoc': {'objectivity': 0.9375, 'pos_vs_neg': 0.0625},
#               'ad_hominem': {'objectivity': 0.375, 'pos_vs_neg': 0.625},
#               'adactylous': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               'adagio': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               'adamant': {'objectivity': 0.25, 'pos_vs_neg': -0.75},
#               'adamantine': {'objectivity': 0.5833333333337,
#                'pos_vs_neg': -0.24999999999970002},
#               'adaptable': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adaptational': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adaptative': {'objectivity': 0.75, 'pos_vs_neg': 0.25},
#               'adapted': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adaptive': {'objectivity': 0.75, 'pos_vs_neg': 0.25},
#               'adaxial': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'addable': {'objectivity': 0.5, 'pos_vs_neg': 0.5},
#               'addible': {'objectivity': 0.5, 'pos_vs_neg': 0.5},
#               'addicted': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'addictive': {'objectivity': 0.375, 'pos_vs_neg': -0.625},
#               'additional': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'additive': {'objectivity': 0.8125, 'pos_vs_neg': -0.1875},
#               'addlebrained': {'objectivity': 0.625, 'pos_vs_neg': 0.125},
#               'addled': {'objectivity': 0.5, 'pos_vs_neg': -0.375},
#               'addlepated': {'objectivity': 0.625, 'pos_vs_neg': 0.125},
#               'addressable': {'objectivity': 0.375, 'pos_vs_neg': 0.625},
#               'addressed': {'objectivity': 0.875, 'pos_vs_neg': 0.125},
#               'adducent': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adducting': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adductive': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adenocarcinomatous': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adenoid': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adenoidal': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adept': {'objectivity': 0.375, 'pos_vs_neg': 0.625},
#               'adequate': {'objectivity': 0.75, 'pos_vs_neg': 0.0},
#               'adequate_to': {'objectivity': 0.375, 'pos_vs_neg': 0.125},
#               'adherent': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adhesive': {'objectivity': 0.25, 'pos_vs_neg': -0.25},
#               'adiabatic': {'objectivity': 0.375, 'pos_vs_neg': -0.625},
#               'adient': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adipose': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adjacent': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adjectival': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adjective': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adjudicative': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adjudicatory': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adjunct': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adjunctive': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adjuratory': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adjustable': {'objectivity': 0.625, 'pos_vs_neg': 0.375},
#               'adjusted': {'objectivity': 0.8125, 'pos_vs_neg': 0.0},
#               'adjustive': {'objectivity': 0.25, 'pos_vs_neg': 0.5},
#               'adjuvant': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'administrable': {'objectivity': 0.375, 'pos_vs_neg': 0.625},
#               'administrative': {'objectivity': 0.75, 'pos_vs_neg': 0.25},
#               'admirable': {'objectivity': 0.1875, 'pos_vs_neg': 0.8125},
#               'admired': {'objectivity': 0.5, 'pos_vs_neg': 0.5},
#               'admissible': {'objectivity': 0.125, 'pos_vs_neg': -0.375},
#               'admissive': {'objectivity': 0.5, 'pos_vs_neg': 0.25},
#               'admittable': {'objectivity': 0.375, 'pos_vs_neg': -0.125},
#               'admittible': {'objectivity': 0.375, 'pos_vs_neg': -0.125},
#               'admonishing': {'objectivity': 0.375, 'pos_vs_neg': -0.625},
#               'admonitory': {'objectivity': 0.5625, 'pos_vs_neg': -0.4375},
#               'adnate': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adnexal': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adolescent': {'objectivity': 0.78125, 'pos_vs_neg': 0.03125},
#               'adonic': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adoptable': {'objectivity': 0.25, 'pos_vs_neg': 0.75},
#               'adopted': {'objectivity': 0.5, 'pos_vs_neg': 0.5},
#               'adoptive': {'objectivity': 0.75, 'pos_vs_neg': 0.25},
#               'adorable': {'objectivity': 0.5, 'pos_vs_neg': 0.5},
#               'adored': {'objectivity': 0.625, 'pos_vs_neg': 0.375},
#               'adoring': {'objectivity': 0.4375, 'pos_vs_neg': 0.4375},
#               'adorned': {'objectivity': 0.625, 'pos_vs_neg': 0.375},
#               'adpressed': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adrenal': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adrenergic': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adrenocortical': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adrenocorticotrophic': {'objectivity': 0.5, 'pos_vs_neg': 0.25},
#               'adrenocorticotropic': {'objectivity': 0.5, 'pos_vs_neg': 0.25},
#               'adrift': {'objectivity': 0.8125, 'pos_vs_neg': 0.1875},
#               'adroit': {'objectivity': 0.75, 'pos_vs_neg': 0.25},
#               'adscititious': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adscript': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adscripted': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adsorbable': {'objectivity': 0.75, 'pos_vs_neg': 0.25},
#               'adsorbate': {'objectivity': 0.75, 'pos_vs_neg': 0.25},
#               'adsorbent': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adsorptive': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adulatory': {'objectivity': 0.75, 'pos_vs_neg': 0.25},
#               'adult': {'objectivity': 0.6875, 'pos_vs_neg': 0.1875},
#               'adulterant': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adulterate': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               'adulterated': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               'adulterating': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adulterine': {'objectivity': 0.625, 'pos_vs_neg': -0.375},
#               'adulterous': {'objectivity': 0.3125, 'pos_vs_neg': -0.5625},
#               'adumbrative': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adust': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               'advance': {'objectivity': 0.9375, 'pos_vs_neg': 0.0625},
#               'advanced': {'objectivity': 0.796875, 'pos_vs_neg': 0.140625},
#               'advancing': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'advantageous': {'objectivity': 0.5, 'pos_vs_neg': 0.5},
#               'advective': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adventitial': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adventitious': {'objectivity': 0.625, 'pos_vs_neg': -0.125},
#               'adventive': {'objectivity': 0.25, 'pos_vs_neg': -0.75},
#               'adventuresome': {'objectivity': 0.125, 'pos_vs_neg': 0.375},
#               'adventuristic': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adventurous': {'objectivity': 0.125, 'pos_vs_neg': 0.375},
#               'adverbial': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'adversative': {'objectivity': 0.375, 'pos_vs_neg': -0.125},
#               'adverse': {'objectivity': 0.5625, 'pos_vs_neg': -0.1875},
#               'advertent': {'objectivity': 0.5, 'pos_vs_neg': 0.5},
#               'advertised': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'advisable': {'objectivity': 0.375, 'pos_vs_neg': 0.625},
#               'advised': {'objectivity': 0.75, 'pos_vs_neg': 0.25},
#               'advisory': {'objectivity': 0.75, 'pos_vs_neg': 0.25},
#               'adynamic': {'objectivity': 0.4375, 'pos_vs_neg': -0.5625},
#               'aecial': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'aegean': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'aeolian': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'aeolotropic': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'aeonian': {'objectivity': 0.875, 'pos_vs_neg': 0.125},
#               'aerated': {'objectivity': 0.9375, 'pos_vs_neg': -0.0625},
#               'aerial': {'objectivity': 0.6875, 'pos_vs_neg': -0.0625},
#               'aeriferous': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'aeriform': {'objectivity': 0.6875, 'pos_vs_neg': -0.0625},
#               'aerobic': {'objectivity': 0.75, 'pos_vs_neg': 0.25},
#               'aerobiotic': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'aerodynamic': {'objectivity': 0.8125, 'pos_vs_neg': 0.0625},
#               'aerolitic': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'aerological': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'aeromechanic': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'aeromedical': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'aeronautic': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'aeronautical': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'aerophilatelic': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'aerophilic': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'aerophilous': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'aerosolised': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'aerosolized': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'aery': {'objectivity': 0.375, 'pos_vs_neg': -0.125},
#               'aeschylean': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'aesculapian': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'aesthetic': {'objectivity': 0.5, 'pos_vs_neg': 0.5},
#               'aesthetical': {'objectivity': 0.375, 'pos_vs_neg': 0.625},
#               'aestival': {'objectivity': 0.875, 'pos_vs_neg': 0.125},
#               'aetiologic': {'objectivity': 0.9375, 'pos_vs_neg': 0.0625},
#               'aetiological': {'objectivity': 0.9375, 'pos_vs_neg': 0.0625},
#               'afeard': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               'afeared': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               'afebrile': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'affable': {'objectivity': 0.375, 'pos_vs_neg': 0.625},
#               'affected': {'objectivity': 0.708333333333,
#                'pos_vs_neg': -0.041666666667},
#               'affecting': {'objectivity': 0.375, 'pos_vs_neg': 0.375},
#               'affectional': {'objectivity': 0.25, 'pos_vs_neg': 0.25},
#               'affectionate': {'objectivity': 0.375, 'pos_vs_neg': 0.625},
#               'affective': {'objectivity': 0.25, 'pos_vs_neg': 0.25},
#               'afferent': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'affiliated': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'affinal': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'affine': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'affined': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'affirmable': {'objectivity': 0.375, 'pos_vs_neg': 0.625},
#               'affirmative': {'objectivity': 0.3750000000003,
#                'pos_vs_neg': 0.5416666666662999},
#               'affirmatory': {'objectivity': 0.5, 'pos_vs_neg': 0.5},
#               'affixal': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'affixed': {'objectivity': 0.875, 'pos_vs_neg': 0.125},
#               'affixial': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'afflicted': {'objectivity': 0.1875, 'pos_vs_neg': -0.1875},
#               'afflictive': {'objectivity': 0.125, 'pos_vs_neg': -0.875},
#               'affluent': {'objectivity': 0.75, 'pos_vs_neg': -0.25},
#               'affordable': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'afghan': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'afghani': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'afghanistani': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'afire': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'aflame': {'objectivity': 0.6875, 'pos_vs_neg': 0.0625},
#               'aflare': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'aflicker': {'objectivity': 0.75, 'pos_vs_neg': 0.25},
#               'afloat': {'objectivity': 0.875, 'pos_vs_neg': 0.125},
#               'aflutter': {'objectivity': 0.5, 'pos_vs_neg': -0.25},
#               'afoot': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'aforementioned': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'aforesaid': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'aforethought': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'afoul': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'afraid': {'objectivity': 0.3125, 'pos_vs_neg': -0.5},
#               'african': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'african-american': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'afrikaans': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'afrikaner': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'afro-american': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'afro-asian': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'aft': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'after': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
# ...
#               'benday': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'benefact': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'benefice': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'beneficiate': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'benefit': {'objectivity': 0.375, 'pos_vs_neg': 0.625},
#               'benficiate': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'benight': {'objectivity': 0.7083333333337001,
#                'pos_vs_neg': 0.1249999999997},
#               'benumb': {'objectivity': 0.75, 'pos_vs_neg': -0.25},
#               'beplaster': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bequeath': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'berate': {'objectivity': 0.25, 'pos_vs_neg': -0.75},
#               'bereave': {'objectivity': 0.5, 'pos_vs_neg': -0.5},
#               'berry': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'berth': {'objectivity': 0.9583333333333,
#                'pos_vs_neg': 0.0416666666667},
#               'beseech': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'beseem': {'objectivity': 0.625, 'pos_vs_neg': 0.375},
#               'beset': {'objectivity': 0.9583333333333,
#                'pos_vs_neg': -0.0416666666667},
#               'beshrew': {'objectivity': 0.375, 'pos_vs_neg': -0.375},
#               'besiege': {'objectivity': 0.75, 'pos_vs_neg': -0.25},
#               'besmear': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'besmirch': {'objectivity': 0.625, 'pos_vs_neg': 0.125},
#               'besot': {'objectivity': 0.875, 'pos_vs_neg': 0.125},
#               'bespangle': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bespatter': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bespeak': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bespeckle': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bespot': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'besprinkle': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'best': {'objectivity': 0.875, 'pos_vs_neg': 0.125},
#               'bestialise': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               'bestialize': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               'bestir': {'objectivity': 0.875, 'pos_vs_neg': 0.125},
#               'bestir_oneself': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bestow': {'objectivity': 0.7499999999997,
#                'pos_vs_neg': 0.08333333333370001},
#               'bestrew': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bestride': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bet': {'objectivity': 0.9166666666667,
#                'pos_vs_neg': 0.0833333333333},
#               'bet_on': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'betake_oneself': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bethink': {'objectivity': 0.9375, 'pos_vs_neg': 0.0625},
#               'betide': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'betoken': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'betray': {'objectivity': 0.645833333333,
#                'pos_vs_neg': -0.354166666667},
#               'betroth': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'better': {'objectivity': 0.5, 'pos_vs_neg': 0.5},
#               'bevel': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bewail': {'objectivity': 0.375, 'pos_vs_neg': -0.625},
#               'beware': {'objectivity': 0.5, 'pos_vs_neg': 0.5},
#               'bewhisker': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bewilder': {'objectivity': 0.6875, 'pos_vs_neg': -0.1875},
#               'bewitch': {'objectivity': 0.791666666667,
#                'pos_vs_neg': 0.208333333333},
#               'bewray': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               'bias': {'objectivity': 0.8125, 'pos_vs_neg': 0.1875},
#               'bib': {'objectivity': 0.875, 'pos_vs_neg': 0.125},
#               'bicker': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               'bicycle': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bid': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bide': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'biff': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bifurcate': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bight': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bike': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bilge': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bilk': {'objectivity': 0.90625, 'pos_vs_neg': 0.03125},
#               'bill': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'billet': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'billow': {'objectivity': 0.90625, 'pos_vs_neg': 0.03125},
#               'bin': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bind': {'objectivity': 0.925, 'pos_vs_neg': -0.025},
#               'bind_off': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bind_over': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'binge': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bioassay': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'biodegrade': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'birch': {'objectivity': 0.875, 'pos_vs_neg': 0.125},
#               'bird': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bird-nest': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'birdie': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'birdlime': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'birdnest': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'birdwatch': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'birl': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'birle': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'birr': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'birth': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bisect': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bitch': {'objectivity': 0.75, 'pos_vs_neg': -0.25},
#               'bite': {'objectivity': 0.78125, 'pos_vs_neg': -0.21875},
#               'bite_off': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bite_out': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bitt': {'objectivity': 0.875, 'pos_vs_neg': 0.125},
#               'bitter': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bituminise': {'objectivity': 0.75, 'pos_vs_neg': -0.25},
#               'bituminize': {'objectivity': 0.75, 'pos_vs_neg': -0.25},
#               'bivouac': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blab': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blab_out': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blabber': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'black': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'black_market': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'black_marketeer': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'black_out': {'objectivity': 0.875, 'pos_vs_neg': 0.0},
#               'blackball': {'objectivity': 0.6875, 'pos_vs_neg': -0.3125},
#               'blackberry': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blacken': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blacken_out': {'objectivity': 0.75, 'pos_vs_neg': 0.0},
#               'blackguard': {'objectivity': 0.6875, 'pos_vs_neg': -0.3125},
#               'blackjack': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blacklead': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blackleg': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blacklist': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blackmail': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blacktop': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blackwash': {'objectivity': 0.9375, 'pos_vs_neg': 0.0625},
#               'blame': {'objectivity': 0.791666666667,
#                'pos_vs_neg': -0.208333333333},
#               'blanch': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blandish': {'objectivity': 0.5, 'pos_vs_neg': 0.5},
#               'blank': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blank_out': {'objectivity': 0.625, 'pos_vs_neg': -0.375},
#               'blanket': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blanket_jam': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blare': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blare_out': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blarney': {'objectivity': 0.75, 'pos_vs_neg': 0.25},
#               'blaspheme': {'objectivity': 0.6875, 'pos_vs_neg': 0.1875},
#               'blast': {'objectivity': 0.9125, 'pos_vs_neg': -0.0875},
#               'blast_off': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               'blat': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blat_out': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blate': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blather': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               'blaze': {'objectivity': 0.875,
#                'pos_vs_neg': 0.024999999999999994},
#               'blaze_away': {'objectivity': 0.9583333333333,
#                'pos_vs_neg': 0.0416666666667},
#               'blaze_out': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blaze_up': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blazon': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blazon_out': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bleach': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bleach_out': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blear': {'objectivity': 0.75, 'pos_vs_neg': -0.25},
#               'bleat': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bleed': {'objectivity': 0.975, 'pos_vs_neg': -0.025},
#               'bleep': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blemish': {'objectivity': 0.708333333333,
#                'pos_vs_neg': -0.291666666667},
#               'blench': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blend': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blend_in': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bless': {'objectivity': 0.8125, 'pos_vs_neg': -0.0625},
#               'blether': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               'blight': {'objectivity': 0.75, 'pos_vs_neg': -0.25},
#               'blind': {'objectivity': 0.708333333333,
#                'pos_vs_neg': -0.291666666667},
#               'blindfold': {'objectivity': 0.75, 'pos_vs_neg': 0.25},
#               'blindside': {'objectivity': 0.625, 'pos_vs_neg': -0.375},
#               'blink': {'objectivity': 0.875, 'pos_vs_neg': 0.125},
#               'blink_away': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blinker': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blister': {'objectivity': 0.541666666667,
#                'pos_vs_neg': -0.458333333333},
#               'blither': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               'blitz': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blitzkrieg': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bloat': {'objectivity': 0.625, 'pos_vs_neg': -0.375},
#               'blob': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'block': {'objectivity': 0.9296875, 'pos_vs_neg': -0.0703125},
#               'block_off': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               'block_out': {'objectivity': 0.84375, 'pos_vs_neg': -0.03125},
#               'block_up': {'objectivity': 0.625, 'pos_vs_neg': -0.375},
#               'blockade': {'objectivity': 0.90625, 'pos_vs_neg': -0.09375},
#               'blog': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blood': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bloody': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bloom': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blossom': {'objectivity': 0.9375, 'pos_vs_neg': 0.0625},
#               'blossom_forth': {'objectivity': 0.875, 'pos_vs_neg': 0.125},
#               'blossom_out': {'objectivity': 0.875, 'pos_vs_neg': 0.125},
#               'blot': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blot_out': {'objectivity': 0.75, 'pos_vs_neg': -0.25},
#               'blotch': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bloviate': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blow': {'objectivity': 0.8863636363636,
#                'pos_vs_neg': -0.0568181818182},
#               'blow-dry': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blow_a_fuse': {'objectivity': 0.75, 'pos_vs_neg': -0.25},
#               'blow_off': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               "blow_one's_stack": {'objectivity': 0.75, 'pos_vs_neg': -0.25},
#               'blow_out': {'objectivity': 0.8333333333334, 'pos_vs_neg': 0.0},
#               'blow_out_of_the_water': {'objectivity': 0.625,
#                'pos_vs_neg': 0.375},
#               'blow_over': {'objectivity': 0.875, 'pos_vs_neg': -0.125},
#               'blow_up': {'objectivity': 0.9375, 'pos_vs_neg': 0.0},
#               'blub': {'objectivity': 0.625, 'pos_vs_neg': -0.375},
#               'blubber': {'objectivity': 0.8125, 'pos_vs_neg': -0.1875},
#               'blubber_out': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bludgeon': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blue': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blue-pencil': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blueprint': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bluff': {'objectivity': 0.75, 'pos_vs_neg': -0.125},
#               'bluff_out': {'objectivity': 0.625, 'pos_vs_neg': -0.375},
#               'blunder': {'objectivity': 0.9166666666667,
#                'pos_vs_neg': -0.0833333333333},
#               'blunder_out': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blunt': {'objectivity': 0.925, 'pos_vs_neg': -0.025},
#               'blur': {'objectivity': 0.729166666667,
#                'pos_vs_neg': -0.020833333332999998},
#               'blurt': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blurt_out': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'blush': {'objectivity': 0.875, 'pos_vs_neg': 0.0},
#               'bluster': {'objectivity': 0.8333333333333,
#                'pos_vs_neg': -0.08333333333330001},
#               'board': {'objectivity': 0.96875, 'pos_vs_neg': 0.03125},
#               'board_up': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'boast': {'objectivity': 0.6875, 'pos_vs_neg': 0.0625},
#               'boat': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'boat-race': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bob': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bob_about': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bob_around': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bob_under': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bob_up': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bobble': {'objectivity': 0.25, 'pos_vs_neg': -0.75},
#               'bobsled': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bode': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bodge': {'objectivity': 0.25, 'pos_vs_neg': -0.75},
#               'body': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'body-surf': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'body_forth': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'body_guard': {'objectivity': 0.375, 'pos_vs_neg': -0.625},
#               'bodypaint': {'objectivity': 1.0, 'pos_vs_neg': 0.0},
#               'bog': {'objectivity': 0.625, 'pos_vs_neg': -0.375},
#               'bog_down': {'objectivity': 0.5625, 'pos_vs_neg': -0.4375},
#               ...}})

# %%
def process_text(documents, pos=False):
    '''
    cleans sentences from stop words and punctuation and filters by pos tags if given
    returns cleaned sentence and tokenized sentence
    '''
    nlp = textacy.load_spacy_lang('en_core_web_sm')
    
    texts = []
    tokenised_texts = []

    if pos: # pos can either be False or a list of parts of speech
        for document in tqdm_notebook(nlp.pipe(documents, batch_size=200)):
            assert document.is_parsed
            tokens = [token
                      for token in document 
                      if token.is_stop == False
                      and token.pos_ in pos
                      and token.pos_ != 'PUNCT']
            doc_ = ''
            for token in tokens:
                doc_ += str(token) + ' '
            
            doc_ = doc_.strip()
            texts.append(doc_)
            tokenised_texts.append(tokens)
    
    
    else:    
        for document in tqdm_notebook(nlp.pipe(documents, batch_size=200)):
            assert document.is_parsed
            tokens = [token
                      for token in document 
                      if token.is_stop == False
                      and token.pos_ != 'PUNCT']
            doc_ = ''
            for token in tokens:
                doc_ += str(token) + ' '
            
            doc_ = doc_.strip()
            texts.append(doc_)
            tokenised_texts.append(tokens)
            
    return texts, tokenised_texts

# %%
pos = ['noun', 'adj', 'verb', 'adv']

# %%
process_text(df['comment_clean'][:2], pos=pos)
# Out:
# /Users/jamesmorley/opt/anaconda3/envs/textacy/lib/python3.7/site-packages/ipykernel_launcher.py:12: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   if sys.path[0] == '':
# 0it [00:00, ?it/s]
# /Users/jamesmorley/opt/anaconda3/envs/textacy/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: [W107] The property `Doc.is_parsed` is deprecated. Use `Doc.has_annotation("DEP")` instead.
#   del sys.path[0]
# (['', ''], [[], []])

# %%
processed_quotes, tokenised_quotes = process_text(df['comment_clean'], pos=pos)
# Out:
# /Users/jamesmorley/opt/anaconda3/envs/textacy/lib/python3.7/site-packages/ipykernel_launcher.py:12: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   if sys.path[0] == '':
# 0it [00:00, ?it/s]
# /Users/jamesmorley/opt/anaconda3/envs/textacy/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: [W107] The property `Doc.is_parsed` is deprecated. Use `Doc.has_annotation("DEP")` instead.
#   del sys.path[0]

# %%
df['processed_quote'] = processed_quotes
df['tokenised_quotes'] = tokenised_quotes

# %%
df.head()
# Out:
#        user                        title  \
# 0  JiffyBag                      RE: SAS
# 1  JiffyBag                      RE: SAS
# 2  rosso123  Newcrest pulling a fast one
# 3  JiffyBag   RE: Why would u short this
# 4  Philbrim                 Ups n downs.
#
#                                              comment     opinion  price  \
# 0  For me, it was just a fun exercise to do, and ...  No Opinion   13.8
# 1  Hi Walkabout,I fully acknoweldege your rationa...  No Opinion   13.8
# 2  NCM wants this 5% done and dusted asap, otherw...  No Opinion   13.8
# 3  Merc,It would be fantastic if someone could ac...  No Opinion   13.8
# 4  We go down 5% and most people are so volatile....  No Opinion   13.8
#
#      datetime                                      comment_clean  \
# 0  2022-01-31  for me it was just a fun exercise to do and we...
# 1  2022-01-31  hi walkabouti fully acknoweldege your rational...
# 2  2022-01-31  ncm wants this done and dusted asap otherwise ...
# 3  2022-01-31  mercit would be fantastic if someone could act...
# 4  2022-01-31  we go down and most people are so volatile we ...
#
#                                      processed_quote  \
# 0  fun exercise information actually transpires u...
# 1  walkabouti fully acknoweldege rationale etcmy ...
# 2  wants dusted asap pay higher price simple asse...
# 3  fantastic actually short dream know satisfying...
# 4  people volatile best buddies board personally ...
#
#                                     tokenised_quotes
# 0  [fun, exercise, information, actually, transpi...
# 1  [walkabouti, fully, acknoweldege, rationale, e...
# 2  [wants, dusted, asap, pay, higher, price, simp...
# 3  [fantastic, actually, short, dream, know, sati...
# 4  [people, volatile, best, buddies, board, perso...

# %%
def scorer(parsed):
    """
    Determines the average objectivity and positive-versus-negative scores 
    for a given sentence
    """
   
    obj_scores, pvn_scores = [], []
    for token in parsed:
        try:
            obj_scores.append(sen_dict[token.pos_][token.lemma_]['objectivity'])
            pvn_scores.append(sen_dict[token.pos_][token.lemma_]['pos_vs_neg'])
        except:
            pass
        
    # set default values if no token found
    if not obj_scores:
        obj_scores = [1.]
    if not pvn_scores:
        pvn_scores = [0.]
        
    return [np.mean(obj_scores), np.mean(pvn_scores)]

# %%
scores = df['tokenised_quotes'].map(scorer)
df['objectivity_avg'] = scores.map(lambda x: x[0])
df['polarity_avg'] = scores.map(lambda x: x[1])

# %%
df['quote_len'] = df.comment.map(lambda x: len(x.split()))
dfs = df[df.quote_len > 10]

# %%
dfs = dfs[dfs['opinion'] != 'No Opinion']

# %%
df.shape
# Out:
# (122597, 12)

# %%
dfs.shape
# Out:
# (13045, 12)

# %%
pos = ['Strong Buy', 'Buy']
neg = ['Sell', 'Strong Sell', 'Weak Sell', 'Hold', 'Weak Buy']

# %%
dfs['pos'] = ['pos' if i in pos else 'neg' for i in dfs.opinion]

# %%
sns.pairplot(dfs, vars=['objectivity_avg', 'polarity_avg', 'quote_len'], hue='pos', 
             plot_kws={'alpha': 0.2}, height=5)
plt.show()

# %%
df.head()
# Out:
#        user                        title  \
# 0  JiffyBag                      RE: SAS
# 1  JiffyBag                      RE: SAS
# 2  rosso123  Newcrest pulling a fast one
# 3  JiffyBag   RE: Why would u short this
# 4  Philbrim                 Ups n downs.
#
#                                              comment     opinion  price  \
# 0  For me, it was just a fun exercise to do, and ...  No Opinion   13.8
# 1  Hi Walkabout,I fully acknoweldege your rationa...  No Opinion   13.8
# 2  NCM wants this 5% done and dusted asap, otherw...  No Opinion   13.8
# 3  Merc,It would be fantastic if someone could ac...  No Opinion   13.8
# 4  We go down 5% and most people are so volatile....  No Opinion   13.8
#
#      datetime                                      comment_clean  \
# 0  2022-01-31  for me it was just a fun exercise to do and we...
# 1  2022-01-31  hi walkabouti fully acknoweldege your rational...
# 2  2022-01-31  ncm wants this done and dusted asap otherwise ...
# 3  2022-01-31  mercit would be fantastic if someone could act...
# 4  2022-01-31  we go down and most people are so volatile we ...
#
#                                      processed_quote  \
# 0  fun exercise information actually transpires u...
# 1  walkabouti fully acknoweldege rationale etcmy ...
# 2  wants dusted asap pay higher price simple asse...
# 3  fantastic actually short dream know satisfying...
# 4  people volatile best buddies board personally ...
#
#                                     tokenised_quotes  objectivity_avg  \
# 0  [fun, exercise, information, actually, transpi...         0.959764
# 1  [walkabouti, fully, acknoweldege, rationale, e...         0.946414
# 2  [wants, dusted, asap, pay, higher, price, simp...         0.860417
# 3  [fantastic, actually, short, dream, know, sati...         0.723999
# 4  [people, volatile, best, buddies, board, perso...         0.908541
#
#    polarity_avg  quote_len
# 0      0.023401         50
# 1      0.005866        154
# 2      0.024200         68
# 3      0.060552         26
# 4      0.038820         77

# %%
# view the top 10 comments for polarity ie the most positive

for quote in dfs.sort_values('polarity_avg', ascending=False)['comment'][0:10]:
    print(quote)
    print('============================================================\n')
# Out:
# Like that, nice one.Will we get a Tuesday RNS ? It's been a while :))
# ============================================================
#
# Wasred, I have to agreeA poet I never will beAlthough thereâs no guaranteeAnd no-one can really foreseeJust how successful will be GGP?
# ============================================================
#
# Merry Christmas all. Everyone here is happy.  Of all the aim we are lucky to be here.
# ============================================================
#
# Redirons, I would reckon he is 1oz in 20million oz, and we are very lucky to have him.GLA
# ============================================================
#
# Thanks TigMorecombe and Wise ?I take it you enjoyed it then :))
# ============================================================
#
# Hi SamplankYou can call me what you like :))Everyone on Wsbn are at the moment:))Am I bovvered
# ============================================================
#
# Hi Speedy,Confirming that I would like one of these too as and when available.Many thanks,Curdy
# ============================================================
#
# Good luck to you in whatever you do next TMT - best regards.
# ============================================================
#
# BUY buy buy. BUY buy buy BUY buy buy BUY buy buy buy . goodbye Sorter's Don't cryfor those that don't remember Mary Hopkins 1969 Lol ATB
# ============================================================
#
# And that must go down as one of the best rants - ever.
# ============================================================

# %%
# view the bottom 10 comments for polarity ie the most negative

for quote in dfs.sort_values('polarity_avg', ascending=True)['comment'][0:10]:
    print(quote)
    print('============================================================\n')
# Out:
# Apologies it was HNR but bottom drawered it and now itâs in profit.MYbe PRIM can do the same
# ============================================================
#
# Canât wait for Monday. It is sad but I hate weekends.
# ============================================================
#
# Can see why you are called Marmite! You either like it or you hate it.
# ============================================================
#
# first hour always manic on a monday rnslift off soonwell done LTHs
# ============================================================
#
# Cup half empty Monty, sorry empty. I don't have to be negative short termATBViking
# ============================================================
#
# Oh, no: now I'll be mesmerised by the ask as well!
# ============================================================
#
# Merc. That are pathetic and so dim that they think we canât see through them. Embarrassed for them.
# ============================================================
#
# Canât see that GDXJ would sell at this price and the volume is really stagnant. Could be wrong but I just canâtSee it.
# ============================================================
#
# Timeserved I think you are a very disruptive negative poster and one not to be trusted.You give nothing to this board!!You are not wanted here !!!
# ============================================================
#
# Just had an earthquake here. Anything to do with 17 getting hit. lolGLA
# ============================================================

# %% [markdown]
# ### Using Vader Sentiment Analyzer

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
vader = SentimentIntensityAnalyzer()

# %%
dfs.opinion.value_counts()
# Out:
# Strong Buy     10781
# Hold            1756
# Buy              483
# Sell               9
# Weak Buy           9
# Strong Sell        5
# Weak Sell          2
# Name: opinion, dtype: int64

# %%
dfs[dfs['opinion'] == 'Strong Sell']
# Out:
#                   user                      title  \
# 15285         wasred15              What the Hell
# 22596         xeverton               RE: Newcrest
# 45470       DStrat1274    Carrying heavy bags....
# 75545         IndyNial  RE: Valueing the deposit.
# 105427  EnricoPallazzo                    RE: 11p
#
#                                                   comment      opinion  price  \
# 15285   Here we go with your 3-6 posts '1 month old do...  Strong Sell  17.45
# 22596   Hydrogen, really donât know why you have to ...  Strong Sell  16.10
# 45470   under water with paper hands?  Then y'all know...  Strong Sell  21.65
# 75545   Don't beat yourself up Sproutsdave, it's an ea...  Strong Sell  28.05
# 105427  Roger that! To improve the effectiveness of th...  Strong Sell  16.95
#
#           datetime                                      comment_clean  \
# 15285   2021-11-01  here we go with your posts month old dodge acc...
# 22596   2021-09-29  hydrogen really dont know why you have to just...
# 45470   2021-04-14  under water with paper hands then yall know wh...
# 75545   2020-12-11  dont beat yourself up sproutsdave its an easy ...
# 105427  2020-09-09  roger that to improve the effectiveness of thi...
#
#                                           processed_quote  \
# 15285   posts month old account long believe spreading...
# 22596   hydrogen know justify nuisance appears enjoy c...
# 45470                        water paper hands know blame
# 75545   beat sproutsdave easy mistake actually ate spr...
# 105427  improve effectiveness procedure set opinion st...
#
#                                          tokenised_quotes  objectivity_avg  \
# 15285   [posts, month, old, account, long, believe, sp...         0.851729
# 22596   [hydrogen, know, justify, nuisance, appears, e...         0.790936
# 45470                  [water, paper, hands, know, blame]         0.898647
# 75545   [beat, sproutsdave, easy, mistake, actually, a...         0.828100
# 105427  [improve, effectiveness, procedure, set, opini...         0.815391
#
#         polarity_avg  quote_len  pos
# 15285       0.047148        453  neg
# 22596       0.101763         57  neg
# 45470      -0.006331         11  neg
# 75545       0.019712         38  neg
# 105427      0.066484         21  neg

# %%
vader.polarity_scores(dfs.comment_clean[105427])
# Out:
# {'neg': 0.0, 'neu': 0.744, 'pos': 0.256, 'compound': 0.7351}

# %%
vader.polarity_scores(dfs.processed_quote[105427])
# Out:
# {'neg': 0.0, 'neu': 0.53, 'pos': 0.47, 'compound': 0.7351}

# %%
vader_scores = df['processed_quote'].map(vader.polarity_scores)

# %%
vader_scores
# Out:
# <122597x4 sparse matrix of type '<class 'numpy.float64'>'
# 	with 490388 stored elements in Compressed Sparse Row format>

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
dvec = DictVectorizer()

vader_scores = dvec.fit_transform(vader_scores)
vader_scores
# Out:
# <122597x4 sparse matrix of type '<class 'numpy.float64'>'
# 	with 490388 stored elements in Compressed Sparse Row format>

# %%
dvec.feature_names_
# Out:
# ['compound', 'neg', 'neu', 'pos']

# %%
for i, col in enumerate(dvec.feature_names_):
    df['vader_{}'.format(col)] = vader_scores[:, i].toarray().ravel()

# %%
df
# Out:
#                   user                        title  \
# 0             JiffyBag                      RE: SAS
# 1             JiffyBag                      RE: SAS
# 2             rosso123  Newcrest pulling a fast one
# 3             JiffyBag   RE: Why would u short this
# 4             Philbrim                 Ups n downs.
# ...                ...                          ...
# 122593     WelshFalcon                RE: Diversify
# 122594          panama                RE: Diversify
# 122595  EnricoPallazzo                 Bid dropping
# 122596          Dip666                RE: Diversify
# 122597  EnricoPallazzo         RE: Satellite Update
#
#                                                   comment     opinion  price  \
# 0       For me, it was just a fun exercise to do, and ...  No Opinion   13.8
# 1       Hi Walkabout,I fully acknoweldege your rationa...  No Opinion   13.8
# 2       NCM wants this 5% done and dusted asap, otherw...  No Opinion   13.8
# 3       Merc,It would be fantastic if someone could ac...  No Opinion   13.8
# 4       We go down 5% and most people are so volatile....  No Opinion   13.8
# ...                                                   ...         ...    ...
# 122593  My thoughts on GGP vs others in the area is ve...  No Opinion   12.1
# 122594  Good luck QF and you being quite Frank here so...  No Opinion   12.1
# 122595  Another big buy just under 12p must be filled ...  Strong Buy   12.1
# 122596  Hi QF, From another perspective, it might be r...  No Opinion   12.1
# 122597  Thanks a lot! Powering ahead towards another s...  Strong Buy   12.1
#
#           datetime                                      comment_clean  \
# 0       2022-01-31  for me it was just a fun exercise to do and we...
# 1       2022-01-31  hi walkabouti fully acknoweldege your rational...
# 2       2022-01-31  ncm wants this done and dusted asap otherwise ...
# 3       2022-01-31  mercit would be fantastic if someone could act...
# 4       2022-01-31  we go down and most people are so volatile we ...
# ...            ...                                                ...
# 122593  2020-06-24  my thoughts on ggp vs others in the area is ve...
# 122594  2020-06-24  good luck qf and you being quite frank here so...
# 122595  2020-06-24  another big buy just under p must be filled at...
# 122596  2020-06-24  hi qf from another perspective it might be reg...
# 122597  2020-06-24  thanks a lot powering ahead towards another se...
#
#                                           processed_quote  \
# 0       fun exercise information actually transpires u...
# 1       walkabouti fully acknoweldege rationale etcmy ...
# 2       wants dusted asap pay higher price simple asse...
# 3       fantastic actually short dream know satisfying...
# 4       people volatile best buddies board personally ...
# ...                                                   ...
# 122593  thoughts ggp area simplisticyes trucking dista...
# 122594  good luck frank good thatlike mushroom growing...
# 122595  big buy p filled moment bid dropped ask stayin...
# 122596  perspective regarded feel late party ggp takin...
# 122597  thanks lot powering ahead set brilliant result...
#
#                                          tokenised_quotes  objectivity_avg  \
# 0       [fun, exercise, information, actually, transpi...         0.959764
# 1       [walkabouti, fully, acknoweldege, rationale, e...         0.946414
# 2       [wants, dusted, asap, pay, higher, price, simp...         0.860417
# 3       [fantastic, actually, short, dream, know, sati...         0.723999
# 4       [people, volatile, best, buddies, board, perso...         0.908541
# ...                                                   ...              ...
# 122593  [thoughts, ggp, area, simplisticyes, trucking,...         0.902830
# 122594  [good, luck, frank, good, thatlike, mushroom, ...         0.842566
# 122595  [big, buy, p, filled, moment, bid, dropped, as...         0.889746
# 122596  [perspective, regarded, feel, late, party, ggp...         0.813973
# 122597  [thanks, lot, powering, ahead, set, brilliant,...         0.904225
#
#         polarity_avg  quote_len  vader_compound  vader_neg  vader_neu  \
# 0           0.023401         50          0.5106      0.000      0.798
# 1           0.005866        154          0.5994      0.079      0.776
# 2           0.024200         68          0.4939      0.144      0.652
# 3           0.060552         26          0.8225      0.000      0.368
# 4           0.038820         77          0.7430      0.072      0.658
# ...              ...        ...             ...        ...        ...
# 122593      0.045793        149          0.8885      0.000      0.824
# 122594      0.013865        108          0.9808      0.051      0.415
# 122595      0.052934         29          0.0000      0.000      1.000
# 122596      0.030148         91          0.8442      0.103      0.576
# 122597      0.023549         35          0.7717      0.000      0.691
#
#         vader_pos
# 0           0.202
# 1           0.145
# 2           0.204
# 3           0.632
# 4           0.270
# ...           ...
# 122593      0.176
# 122594      0.534
# 122595      0.000
# 122596      0.321
# 122597      0.309
#
# [122597 rows x 16 columns]

# %% [markdown]
# ### Output to csv...

# %%
# df.to_csv('resources/sentiments.csv', index=False)
